# %%
import pandas as pd

# 데이터 로드
applicatns_df = pd.read_csv(r'C:\Users\leezoo\Desktop\졸업작품\graduation_inu\junk_data\junk_data\applicants.csv')
team_leader_df = pd.read_csv(r'C:\Users\leezoo\Desktop\졸업작품\graduation_inu\junk_data\junk_data\team_leader.csv')

applicatns_df
# Out:
#     id                                       requirements
# 0    1  Python, Data Science, Machine Learning, Big Da...
# 1    2  JavaScript, Frontend, React, Web Development, ...
# 2    3  Java, Backend, Microservices, Spring Boot, RES...
# 3    4  C++, Game Development, Unreal Engine, Unity, G...
# 4    5  Ruby, Ruby on Rails, Web Development, Backend ...
# 5    6  C#, .NET, ASP.NET, MVC, Web Development, Windo...
# 6    7  Go, Microservices, Cloud Computing, Kubernetes...
# 7    8  PHP, Laravel, Symfony, Web Development, MySQL,...
# 8    9  Swift, iOS Development, Mobile Development, Ob...
# 9   10  Perl, Scripting, System Administration, Automa...
# 10  11  Python, Data Analysis, Machine Learning, Deep ...
# 11  12  JavaScript, Frontend Development, React, Web D...
# 12  13  Java, Spring Boot, Microservices, RESTful Web ...
# 13  14  C++, Game Development, Unreal Engine, Unity, G...
# 14  15  Ruby, Ruby on Rails, Web Development, Backend ...
# ...
